# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

from docile.dataset import Dataset


docile_dataset="docile221124-3"

DATASET_EXPORTS_DEFAULT_PATH = Path("/datasets")
dataset_path = DATASET_EXPORTS_DEFAULT_PATH / docile_dataset

docile_prefinal = Dataset.load(dataset_path, "all")
docile_prefinal_train = Dataset.load(dataset_path, "train")
docile_prefinal_val = Dataset.load(dataset_path, "val")
docile_prefinal_test = Dataset.load(dataset_path, "test")
# Out:
# Loading documents for docile221124-3/all: 100%|██████████| 5902/5902 [00:00<00:00, 56916.05it/s]
# Loading documents for docile221124-3/train: 100%|██████████| 4402/4402 [00:00<00:00, 76252.51it/s]
# Loading documents for docile221124-3/val: 100%|██████████| 500/500 [00:00<00:00, 13432.17it/s]
# Loading documents for docile221124-3/test: 100%|██████████| 1000/1000 [00:00<00:00, 72778.61it/s]

# %%
import _collections_abc
from collections import Counter


class RecursiveCounter(Counter):
    """Counter that can have RecursiveCounters as values."""
    def __missing__(self, elem):
        if elem not in self:
            return self.__class__({})

    def __iadd__(self, other):
        if isinstance(other, int) and not self:
            return other
        for key, val in other.items():
            self[key] += val
        return self
    
    def total_sum(self):
        total_sum = 0
        for val in self.values():
            if isinstance(val, int):
                total_sum += val
            else:
                total_sum += val.total_sum()
        return total_sum
    
    def __hash__(self) -> int:
        return hash(tuple(sorted(self.items())))
                
    def __le__(self, other: "RecursiveCounter") -> bool:
        return self.total_sum() <= other.total_sum()
    
    def update(self, iterable=None, /, **kwds):
        '''Like dict.update() but add counts instead of replacing them.
        Source can be an iterable, a dictionary, or another Counter instance.
        >>> c = Counter('which')
        >>> c.update('witch')           # add elements from another iterable
        >>> d = Counter('watch')
        >>> c.update(d)                 # add elements from another counter
        >>> c['h']                      # four 'h' in which, witch, and watch
        4
        '''
        # The regular dict.update() operation makes no sense here because the
        # replace behavior results in the some of original untouched counts
        # being mixed-in with all of the other counts for a mismash that
        # doesn't have a straight-forward interpretation in most counting
        # contexts.  Instead, we implement straight-addition.  Both the inputs
        # and outputs are allowed to contain zero and negative counts.

        if iterable is not None:
            if isinstance(iterable, _collections_abc.Mapping):
                if self:
                    if isinstance(iterable, RecursiveCounter):
                        self += iterable
                    else:
                        self += RecursiveCounter(iterable)
                else:
                    # fast path when counter is empty
                    super().update(iterable)
            else:
                for elem in iterable:
                    if isinstance(elem, RecursiveCounter):
                        self += elem
                    else:
                        self[elem] += 1
        if kwds:
            self.update(kwds)
    
    def most_common_recursive(self, max_count: int = 0, reverse: bool = False):
        items_sorted = []
        to = max_count if max_count else len(self)
        for key, val in sorted(self.items(), key=lambda kv: kv[1], reverse=not reverse)[:to]:
            if isinstance(val, int):
                items_sorted.append([f"{key}:{val}"])
            else:
                items_sorted.append((key, val.total_sum(), val.most_common_recursive(max_count, reverse)))
        return items_sorted

    def _keep_positive(self):
        pass

# %%
stats = RecursiveCounter()

datasets = [docile_prefinal_train, docile_prefinal_val, docile_prefinal_test]

for doc in docile_prefinal:
    for dataset in datasets:
        try:
            _d = dataset[doc.docid]
        except:
            pass
        else:
            # print([{f.fieldtype: RecursiveCounter([dataset.split_name])} for f in doc.annotation.fields])
            # rc = RecursiveCounter([RecursiveCounter({f.fieldtype: RecursiveCounter([dataset.split_name])}) for f in doc.annotation.fields])
            stats["KILE-fieldtypes"] += RecursiveCounter(RecursiveCounter({f.fieldtype: RecursiveCounter([dataset.split_name])}) for f in doc.annotation.fields)
            stats["LIR-fieldtypes"] += RecursiveCounter(RecursiveCounter({f.fieldtype: RecursiveCounter([dataset.split_name])}) for f in doc.annotation.li_fields)

# %%
stats.most_common_recursive(True)
# Out:
# [('KILE-fieldtypes',
#   72947,
#   [('iban', 5, ['train:4', 'test:1']),
#    ('recipient_vat_id', 9, ['train:8', 'val:1']),
#    ('recipient_ic', 12, ['train:6', 'test:4', 'val:2']),
#    ('bic', 27, ['train:22', 'test:4', 'val:1']),
#    ('sender_vat_id', 33, ['train:33']),
#    ('recipient_dic', 41, ['train:21', 'val:14', 'test:6']),
#    ('sender_ic', 53, ['train:46', 'test:7']),
#    ('tax_detail_rate', 68, ['train:59', 'test:6', 'val:3']),
#    ('bank_num', 96, ['train:81', 'test:11', 'val:4']),
#    ('account_num', 136, ['train:109', 'test:14', 'val:13']),
#    ('var_sym', 195, ['train:137', 'test:39', 'val:19']),
#    ('sender_order_id', 228, ['train:173', 'test:28', 'val:27']),
#    ('customer_delivery_addrline', 333, ['train:269', 'test:44', 'val:20']),
#    ('customer_other_addrline', 349, ['train:267', 'test:60', 'val:22']),
#    ('recipient_delivery_name', 354, ['train:283', 'test:47', 'val:24']),
#    ('amount_paid', 445, ['train:358', 'test:64', 'val:23']),
#    ('tax_detail_base', 516, ['train:409', 'test:63', 'val:44']),
#    ('tax_detail_total', 531, ['train:408', 'test:77', 'val:46']),
#    ('tax_detail_tax', 574, ['train:453', 'test:84', 'val:37']),
#    ('customer_order_id', 574, ['train:462', 'test:70', 'val:42']),
#    ('amount_total_tax', 621, ['train:486', 'test:88', 'val:47']),
#    ('sender_email', 689, ['train:525', 'test:105', 'val:59']),
#    ('sender_dic', 774, ['train:603', 'test:114', 'val:57']),
#    ('amount_total_base', 837, ['train:674', 'test:102', 'val:61']),
#    ('date_due', 914, ['train:660', 'test:173', 'val:81']),
#    ('recipient_other_name', 1533, ['train:1108', 'test:267', 'val:158']),
#    ('sender_other_addrline', 1620, ['train:1235', 'test:256', 'val:129']),
#    ('sender_other_name', 1904, ['train:1463', 'test:306', 'val:135']),
#    ('customer_id', 2114, ['train:1636', 'test:306', 'val:172']),
#    ('terms', 2311, ['train:1767', 'test:329', 'val:215']),
#    ('order_id', 3486, ['train:2623', 'test:612', 'val:251']),
#    ('currency_code', 4208, ['train:3145', 'test:725', 'val:338']),
#    ('sender_addrline', 5187, ['train:3948', 'test:835', 'val:404']),
#    ('customer_billing_addrline', 5366, ['train:4079', 'test:830', 'val:457']),
#    ('sender_name', 5595, ['train:4212', 'test:930', 'val:453']),
#    ('invoice_id', 6163, ['train:4713', 'test:978', 'val:472']),
#    ('amount_total', 6175, ['train:4607', 'test:1024', 'val:544']),
#    ('date_issue', 6234, ['train:4715', 'test:1017', 'val:502']),
#    ('amount_due', 6295, ['train:4707', 'test:1048', 'val:540']),
#    ('recipient_name', 6342, ['train:4728', 'test:1066', 'val:548'])]),
#  ('LIR-fieldtypes',
#   250025,
#   [('table_column_ean', 6, ['train:6']),
#    ('table_column_discount_rate', 24, ['train:15', 'test:9']),
#    ('table_column_hts_number', 40, ['train:37', 'test:3']),
#    ('table_column_discount amount', 61, ['train:31', 'test:30']),
#    ('table_column_weight', 95, ['train:79', 'test:12', 'val:4']),
#    ('table_column_rate', 100, ['train:64', 'test:34', 'val:2']),
#    ('table_column_name', 288, ['train:258', 'test:24', 'val:6']),
#    ('table_column_po_id', 289, ['train:181', 'test:75', 'val:33']),
#    ('table_column_tax', 294, ['train:266', 'test:22', 'val:6']),
#    ('table_column_currency', 1283, ['train:782', 'test:268', 'val:233']),
#    ('table_column_uom', 1702, ['train:1432', 'test:189', 'val:81']),
#    ('table_column_amount_base', 2715, ['train:1826', 'test:571', 'val:318']),
#    ('table_column_amount_total_base',
#     4130,
#     ['train:2840', 'test:802', 'val:488']),
#    ('table_column_code', 9342, ['train:7582', 'test:1185', 'val:575']),
#    ('table_column_position', 9755, ['train:7593', 'test:1546', 'val:616']),
#    ('table_column_amount', 18947, ['train:15291', 'test:2205', 'val:1451']),
#    ('table_column_quantity', 22846, ['train:16934', 'test:3429', 'val:2483']),
#    ('table_column_amount_total',
#     23756,
#     ['train:17977', 'test:3507', 'val:2272']),
#    ('table_column_description',
#     27447,
#     ['train:21537', 'test:3874', 'val:2036']),
#    ('table_column_date', 31990, ['train:25875', 'test:3616', 'val:2499']),
#    ('table_column_other', 94915, ['train:75417', 'test:12408', 'val:7090'])])]

# %%
from docile.dataset import Field

header_stats = RecursiveCounter()

for doc in docile_prefinal:
    # print([{f.fieldtype: RecursiveCounter([dataset.split_name])} for f in doc.annotation.fields])
    # rc = RecursiveCounter([RecursiveCounter({f.fieldtype: RecursiveCounter([dataset.split_name])}) for f in doc.annotation.fields])
    header_fields = [Field.from_annotation(a) for a in doc.annotation.content["line_item_headers"]]
    header_stats += RecursiveCounter(RecursiveCounter({f.fieldtype: RecursiveCounter([f.text.lower()])}) for f in header_fields)

# %%
len(header_stats.keys())
# Out:
# 21

# %%
header_stats.most_common_recursive(25)
# Out:
# [('table_column_other',
#   13597,
#   [['length:1305'],
#    ['time:1236'],
#    ['len:834'],
#    ['type:498'],
#    ['day:324'],
#    ['start/end time:297'],
#    ['days:251'],
#    ['times:246'],
#    ['dur:206'],
#    ['daypart:199'],
#    ['start:187'],
#    ['station:179'],
#    ['m:170'],
#    ['mtwtfss:143'],
#    ['time period:123'],
#    ['dp:120'],
#    ['end:116'],
#    ['ch:104'],
#    ['c/t:103'],
#    ['start time:94'],
#    ['run times:93'],
#    ['tu:93'],
#    ['daypart\ncode:91'],
#    ['date:90'],
#    ['scheduled time:90']]),
#  ('table_column_date',
#   4444,
#   [['date:1342'],
#    ['end date:488'],
#    ['start date:471'],
#    ['start:276'],
#    ['dates:231'],
#    ['end:175'],
#    ['end\ndate:128'],
#    ['start\ndate:126'],
#    ['air date:107'],
#    ['run date:104'],
#    ['run dates:102'],
#    ['stop:77'],
#    ['effective dates:70'],
#    ['day:68'],
#    ['days:49'],
#    ['date range:46'],
#    ['dates to run:38'],
#    ['period:33'],
#    ['from:32'],
#    ['thru:32'],
#    ['days of:31'],
#    ['invoice date:30'],
#    ['order date:29'],
#    ['ship date:27'],
#    ['entered:27']]),
#  ('table_column_quantity',
#   4338,
#   [['qty:689'],
#    ['total\nspots:413'],
#    ['spots:400'],
#    ['quantity:347'],
#    ['spots/\nweek:200'],
#    ['total:110'],
#    ['spots /\nweek:109'],
#    ['hours:85'],
#    ['# of spots:81'],
#    ['total spots:75'],
#    ['spots\n/wk:67'],
#    ['number\nof cases:67'],
#    ['quantity\nto case:67'],
#    ['sp/dy:53'],
#    ['total\nunits:51'],
#    ['billable units:47'],
#    ['week\ntotal:46'],
#    ['# of\nbroadcasts:46'],
#    ['ord.\nspots:43'],
#    ['shipped:41'],
#    ['totl\nspts:40'],
#    ['ads:39'],
#    ['spts\n/wk:38'],
#    ['ordered:34'],
#    ['tot\nspts:34']]),
#  ('table_column_description',
#   3665,
#   [['description:1682'],
#    ['program:303'],
#    ['product:110'],
#    ['product type:89'],
#    ['brand:75'],
#    ['item description:67'],
#    ['program name:67'],
#    ['log name:46'],
#    ['product description:44'],
#    ['(program):38'],
#    ['days:37'],
#    ['description of services:36'],
#    ['market station:34'],
#    ['line type / break type (ref #):33'],
#    ['data:31'],
#    ['product\ndescription:30'],
#    ['vehicle:29'],
#    ['product category\ncommission catg.:29'],
#    ['this is a progress bill:27'],
#    ['order details:25'],
#    ['program title:24'],
#    ['kyca advertising august 2018:23'],
#    ['station:20'],
#    ['daypart (program):18'],
#    ['space:17']]),
#  ('table_column_amount_total',
#   3361,
#   [['amount:824'],
#    ['total:693'],
#    ['total cost:177'],
#    ['rate:164'],
#    ['cost:155'],
#    ['price:100'],
#    ['extension:69'],
#    ['$$:61'],
#    ['gross:59'],
#    ['subtotal:47'],
#    ['net due:46'],
#    ['charges:41'],
#    ['ord.\ncost:40'],
#    ['invoice amt:39'],
#    ['total\n$:35'],
#    ['rebate:31'],
#    ['total amount:30'],
#    ['entry total:30'],
#    ['total $:29'],
#    ['$ total:29'],
#    ['rebate amount:24'],
#    ['extended\ntotal:24'],
#    ['item price:23'],
#    ['dollars:22'],
#    ['total price:21']]),
#  ('table_column_amount',
#   3078,
#   [['rate:2104'],
#    ['price:104'],
#    ['unit price:96'],
#    ['list price:73'],
#    ['stn\ngross:64'],
#    ['unit\namount:46'],
#    ['rate line#:43'],
#    ['gross\nrate:36'],
#    ['item cost:32'],
#    ['charges:31'],
#    ['difference:30'],
#    ['unit\nrate:28'],
#    ['cost:26'],
#    ['gross:26'],
#    ['unit\nprice:20'],
#    ['cost\nper spot:16'],
#    ['amt:15'],
#    ['hourly rate:15'],
#    ['rate/unit:15'],
#    ['charge:13'],
#    ['unit\ncost:13'],
#    ['item\ncost:13'],
#    ['gross\nrate paid:12'],
#    ['gross total:12'],
#    ['station gross\nrate/:11']]),
#  ('table_column_position',
#   1678,
#   [['line:572'],
#    ['ln:317'],
#    ['#:162'],
#    ['line\nno:123'],
#    ['item:108'],
#    ['no:71'],
#    ['line\n#:45'],
#    ['rep\nline#:38'],
#    ['page:36'],
#    ['our line #:30'],
#    ['l#:28'],
#    ['* line:28'],
#    ['line #:18'],
#    ['item#:12'],
#    ['order line:11'],
#    ['day:10'],
#    ['ne:8'],
#    ['date:7'],
#    ['buy\nline:6'],
#    ['line no:5'],
#    ['ine:5'],
#    ['rt:4'],
#    ['line#:3'],
#    ['pos.\nitem:2'],
#    ['line\nno.:2']]),
#  ('table_column_code',
#   1163,
#   [['ad-id:102'],
#    ['line #:63'],
#    ['item:58'],
#    ['item number\n(upc):55'],
#    ['product code:46'],
#    ['dpt\ncode:43'],
#    ['work:43'],
#    ['inventory code:37'],
#    ['copy id:36'],
#    ['station:36'],
#    ['invoice number:32'],
#    ['line:29'],
#    ['airbill number:26'],
#    ['ad-id / isci:26'],
#    ['property:25'],
#    ['daypart\ncode:25'],
#    ['copy/isci:22'],
#    ['copy:21'],
#    ['item #:19'],
#    ['billing code:18'],
#    ['ch:16'],
#    ['item no.:14'],
#    ['type:13'],
#    ['copy#:13'],
#    ['isci:13']]),
#  ('table_column_amount_total_base',
#   725,
#   [['amount:146'],
#    ['total:76'],
#    ['gross amount:45'],
#    ['price:33'],
#    ['ext amt:29'],
#    ['subtotal:28'],
#    ['rate:27'],
#    ['item price:25'],
#    ['net:22'],
#    ['cost:22'],
#    ['extension:20'],
#    ['total $:20'],
#    ['net total:19'],
#    ['$/week:18'],
#    ['extended\nprice:17'],
#    ['weekly total $:15'],
#    ['invoice total:14'],
#    ['extended price:12'],
#    ['net\nordered:11'],
#    ['net amount:10'],
#    ['ord\ncost:10'],
#    ['total cost:8'],
#    ['total price kes:6'],
#    ['extended amount:4'],
#    ['gross\nrate:4']]),
#  ('table_column_amount_base',
#   525,
#   [['rate:255'],
#    ['unit price:78'],
#    ['price:43'],
#    ['amt:29'],
#    ['stn net:23'],
#    ['unit\nprice:21'],
#    ['net rate\npaid:13'],
#    ['net percent\nrate/:7'],
#    ['price each:5'],
#    ['charge:3'],
#    ['unit\nrate:3'],
#    ['einzelpreis\nunit price:2'],
#    ['net rate:2'],
#    ['debit:2'],
#    ['ltem cost:2'],
#    ['po price:2'],
#    ['item cost:2'],
#    ['cost:2'],
#    ['each:2'],
#    ['price/unit:2'],
#    ['price per unit:1'],
#    ['untt price:1'],
#    ['unit prce:1'],
#    ['net ea:1'],
#    ['$850.00:1']]),
#  ('table_column_uom',
#   204,
#   [['unit:52'],
#    ['uom code:43'],
#    ['uom:17'],
#    ['quantity:16'],
#    ['product:8'],
#    ['u of m:8'],
#    ['um:7'],
#    ['invoice\nunit:5'],
#    ['units:4'],
#    ['tkpr:4'],
#    ['ordered:3'],
#    ['su:3'],
#    ['unit price:2'],
#    ['unit\ncost:2'],
#    ['cost\ntype:2'],
#    ["q'ty:2"],
#    ['pr.unit:2'],
#    ['p/u:2'],
#    ['u ot m:1'],
#    ['qty.:1'],
#    ['lo:1'],
#    ['no. of\npkgs.:1'],
#    ['back-ordered:1'],
#    ['amount sent:1'],
#    ['spots/day:1']]),
#  ('table_column_tax',
#   95,
#   [['sales tax:48'],
#    ['tax 1:25'],
#    ['grp:8'],
#    ['tax:4'],
#    ['grp*:4'],
#    ['rate:3'],
#    ['vat:1'],
#    ["rat'\n0.00:1"],
#    ['tax\namount:1']]),
#  ('table_column_name',
#   48,
#   [['performer name:9'],
#    ['name:4'],
#    ['investigator:4'],
#    ['personnel:4'],
#    ['lawyers:3'],
#    ['photographer na:3'],
#    ['passenger name:2'],
#    ['description:2'],
#    ['services provided by:2'],
#    ['timekeeper name:2'],
#    ['resource:2'],
#    ['employee name:2'],
#    ['narme:1'],
#    ['reference:1'],
#    ['salesperson:1'],
#    ['firm matter name:1'],
#    ['authorized by / job / code:1'],
#    ['attorney:1'],
#    ['staff:1'],
#    ['employee:1'],
#    ['author/artist:1']]),
#  ('table_column_hts_number', 39, [['cmdty code:38'], ['mdty co:1']]),
#  ('table_column_weight',
#   34,
#   [['weight:15'],
#    ['gross:3'],
#    ['tare:2'],
#    ['chg wgt:2'],
#    ['gross wages:2'],
#    ['u of m:2'],
#    ['weight (lbs):2'],
#    ['gross\nkgs.:1'],
#    ['gross kilos:1'],
#    ['net kilos:1'],
#    ['net:1'],
#    ['gross\nlbs.:1'],
#    ['tare\nlbs.:1']]),
#  ('table_column_po_id',
#   32,
#   [['contract #:3'],
#    ['job #:3'],
#    ['order:3'],
#    ['ref #:3'],
#    ['alt order:2'],
#    ['ref no:2'],
#    ['order #:2'],
#    ['reference:2'],
#    ['job:1'],
#    ['your reference\nnumber:1'],
#    ['contractnumber:1'],
#    ['order\nnumber:1'],
#    ['po#:1'],
#    ['invoice/order:1'],
#    ['ref. #:1'],
#    ['job\nno.:1'],
#    ['purchase\norder number:1'],
#    ['your order no.:1'],
#    ['invoice # or description:1'],
#    ['contract/\norder #:1']]),
#  ('table_column_currency',
#   24,
#   [['total\nfee:5'],
#    ['$:4'],
#    ['total fee:4'],
#    ['price\nunit.:3'],
#    ['amount in us $:2'],
#    ['price/unit:2'],
#    ['value: dem:1'],
#    ['amount:1'],
#    ['charges:1'],
#    ['cumulative:1']]),
#  ('table_column_discount amount',
#   23,
#   [['discount:9'],
#    ['discount\namount:3'],
#    ['agy disc:2'],
#    ['commission:2'],
#    ['discounts:2'],
#    ['disc:2'],
#    ['amount\nrefunded:1'],
#    ['discount amount:1'],
#    ['cash dsct::1']]),
#  ('table_column_discount_rate',
#   13,
#   [['discounts:9'],
#    ['% share of\npayment:1'],
#    ['discount:1'],
#    ['discount %:1'],
#    ['disc\n%:1']]),
#  ('table_column_rate',
#   10,
#   [['tax-\nable:3'],
#    ['tax\nable:2'],
#    ['tax- \nable:1'],
#    ['skip\nw.:1'],
#    ['tax:1'],
#    ['tax\n%:1'],
#    ['ord\nspots:1']]),
#  ('table_column_ean', 1, [['product:1']])]
